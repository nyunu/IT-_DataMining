# %% [markdown]
# <a href="https://colab.research.google.com/github/nyunu/IT_DataMining/blob/main/IT%EC%99%80_%EB%B9%84%EC%A6%88%EB%8B%88%EC%8A%A4_%ED%98%81%EC%8B%A0_%EA%B8%B0%EB%A7%90%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%EA%B0%9C%EC%9D%B8%EC%BD%94%EB%93%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Company Bankruptcy Prediction**

# %% [markdown]
# ## **< 도메인 지식 >**
# **1. 기업파산이란?** <br>
# 개인이나 사업체가 미지급 채무나 의무를 상환할 수 없을 때 시작되는 법적 절차
#
# **2. 파산 원인** <br>
# 1) <br>
# 데일리한국 ['부도 나는 기업들은 이런 특징이 있다'...한국기업평가 사례분석] <br>
# https://daily.hankooki.com/news/articleView.html?idxno=324323 <br>
# * 실적 부진→신규사업 투자확대→자금 부족→부실
# * 외부차입으로 무리하게 사업을 확장하고, 계열사가 부실해지고, 장기간 판매 부진을 겪는 악순환
# * 영업환경이 나빠져 제품 판매가 줄고 이로 인해 자금 사정이 악화돼 부실로 이어지는 전통적인 부실 <br><br>
#
# 2) <br>
# 시사저널 [거래처 '부도징후' 읽는 방법] <br>
# https://www.sisajournal.com/news/articleView.html?idxno=105562 <br>

# %% [markdown]
# ### **변수**<br>
# Y - 파산여부: class label<br>
# X1 - 이자 전 ROA(C) 및 이자 전 감가상각: 총자산 수익률(C) (ROA : 은행 총자산이익율)<br>
# X2 - 이자 전 ROA(A) 및 세금 후 %: 총 자산 수익률(A)<br>
# X3 - 세후 이자 및 감가상각 전 ROA(B): 총자산 수익률(B)<br>
# X4 - 영업 총이익: 총이익/순매출액<br>
# X5 - 실현된 매출 총이익: 실현된 총이익/순매출액<br>
# X6 - 영업이익률: 영업이익/순매출액<br>
# X7 - 세전 순이자율: 세전 소득/순매출액<br>
# X8 - 세후 순이자율: 순이익/순매출액<br>
# X9 - 비산업 수입 및 지출/수입: 순영업외수익률<br>
# X10 - 연속이자율(세후): 순이익-처분이익 또는 손실/순매출액 제외<br>
# X11 - 운영 비용 비율: 운영비/순매출액<br>
# X12 - 연구개발비율: (연구개발비)/순매출액<br>
# X13 - 현금 흐름 속도: 영업/경상부채로 인한 현금흐름<br>
# X14 - 이자부 부채 이자율: 이자부부채/지분<br>
# X15 - 세율 (A): 실효세율<br>
# X16 - 주당 순가치(B): 주당 장부가액(B)<br>
# X17 - 주당 순가치(A): 주당 장부가액(A)<br>
# X18 - 주당 순가치(C): 주당 장부가치(C)<br>
# X19 - 지난 4시즌간 지속적인 EPS: EPS-순소득<br>
# X20 - 주당 현금 흐름<br>
# X21 - 주당 수익(Yuan ¥): 주당 매출<br>
# X22 - 주당 영업이익(Yuan ¥): 주당 영업이익<br>
# X23 - 세전 1주당 순이익(위안 ¥): 세전 1주당 소득<br>
# X24 - 실현된 매출 총이익 증가율<br>
# X25 - 영업이익 증가율: 영업이익 증가율 <br>
# X26 - 세후 순이익 증가율: 순이익 증가율<br>
# X27 - 정기 순이익 증가율 : 세금 증가 후 영업이익 지속 <br>
# X28 - 지속적인 순이익 증가율: 처분손익을 제외한 순이익 증가율<br>
# X29 - 총 자산 증가율: 총 자산 증가율<br>
# X30 - 순가치 증가율: 총 자본 증가율<br>
# X31 - 총 자산 수익률 증가율: 총 자산 수익률<br>
# X32 - 현금 재투자 %: 현금 재투자 비율<br>
# X33 - 전류비<br>
# X34 - 빠른 비율: 산도 테스트<br>
# X35 - 이자비용비율: 이자비용/총수익<br>
# X36 - 총부채/총 순자산: 총부채/지분율<br>
# X37 - 부채 비율 %: 부채/총 자산<br>
# X38 - 순자산/자산: 자본/총자산<br>
# X39 - 장기자금적합비율(A): (장기부채+지분)/고정자산<br>
# X40 - 차입 의존성: 이자 부담 부채 비용<br>
# X41 - 우발부채/순자산: 우발부채/지분<br>
# X42 - 영업이익/기입자본: 영업이익/자본<br>
# X43 - 세전순이익/기입자본: 세전소득/자본<br>
# X44 - 재고 및 매출채권/순가치: (재고+매출채권)/지분<br>
# X45 - 총 자산 회전율<br>
# X46 - 매출채권회전율<br>
# X47 - 평균 수집일: 미수금 일수<br>
# X48 - 재고 회전율(회)<br>
# X49 - 고정 자산 회전 빈도<br>
# X50 - 순자산 회전율(회수): 자본 회전율<br>
# X51 - 1인당 매출: 직원당 매출 <br>
# X52 - 1인당 영업이익: 직원당 운영 수익<br>
# X53 - 1인당 할당 비율: 직원당 고정 자산<br>
# X54 - 운용 자본 대 총 자산 <br>
# X55 - 빠른 자산/총 자산<br>
# X56 - 유동자산/총자산<br>
# X57 - 현금/총자산<br>
# X58 - 신속한 자산/경상 부채<br>
# X59 - 현금/유동부채<br>
# X60 - 유동자산부채<br>
# X61 - 부채에 대한 운영 자금<br>
# X62 - 재고/운전 자본 <br>
# X63 - 재고/유동부채<br>
# X64 - 유동부채/부채<br>
# X65 - 운영 자본/자본<br>
# X66 - 유동부채/자본<br>
# X67 - 유동자산에 대한 장기부채<br>
# X68 - 총자산 대비 이익잉여금<br>
# X69 - 총수입/총비용<br>
# X70 - 총 비용/자산<br>
# X71 - 유동자산 회전율: 유동자산 대 매출액<br>
# X72 - 빠른 자산 회전율: 신속한 자산 판매<br>
# X73 - 가동 자본 회전율: 영업 자본<br>
# X74 - 현금 회전율: 현금 대 매출액<br>
# X75 - 매출로의 현금 흐름<br>
# X76 - 고정 자산 대 자산 <br>
# X77 - 유동부채<br>
# X78 - 자본에 대한 유동부채<br>
# X79 - 장기 부채에 대한 자본<br>
# X80 - 총 자산에 대한 현금 흐름<br>
# X81 - 부채로의 현금 흐름<br>
# X82 - 자산에 대한 CFO <br>
# X83 - 자본으로의 현금 흐름<br>
# X84 - 유동자산에 대한 유동부채<br>
# X85 - 책임 자산 플래그: 총 책임이 총 자산을 초과하는 경우 1, 그렇지 않은 경우 0<br>
# X86 - 총자산 대비 순이익 <br>
# X87 - GNP 가격 대비 총자산<br>
# X88 - 무신용 구간<br>
# X89 - 매출총이익<br>
# X90 - 주주 자본에 대한 순이익 <br>
# X91 - 자본부채<br>
# X92 - 금융 레버리지(DFL)의 정도 <br>
# X93 - 이자보상비율(EB에 대한 이자비용)IT)<br>
# X94 - 순이익 플래그: 지난 2년 동안 순이익이 마이너스인 경우 1, 그렇지 않은 경우 0<br>
# X95 - 부채에 대한 지분<br>

# %% [markdown]
# ## **Q**
# 1. 변수선택
# - 도메인 지식을 바탕으로 관심있는 변수를 선택
# - 차원축소 -> PCA를 통해 데이터 자체를 변환하여 사용
# - Feature Importance를 이용 .. -> ex) MDI, Drop-Column Importance, Permutation Importance etc ..
#
# <br>
#
# 2. 데이터 불균형
# * oversampling
# * undersampling

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score, make_scorer, accuracy_score, recall_score, precision_score
from sklearn.metrics import confusion_matrix
from sklearn.utils import class_weight

from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.metrics import plot_confusion_matrix

from imblearn.over_sampling import SMOTE

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/drive/MyDrive/data.csv")
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
# df.columns = ['파산여부(Y)', '이자 전 ROA(C) 및 이자 전 감가상각: 총자산 수익률(C)','이자 전 ROA(A) 및 세금 후 %: 총 자산 수익률(A)'
#,'세후 이자 및 감가상각 전 ROA(B): 총자산 수익률(B)','영업 총이익: 총이익/순매출액','실현된 매출 총이익: 실현된 총이익/순매출액'
#,'영업이익률: 영업이익/순매출액','세전 순이자율: 세전 소득/순매출액','세후 순이자율: 순이익/순매출액','비산업 수입 및 지출/수입: 순영업외수익률'
#,'연속이자율(세후): 순이익-처분이익 또는 손실/순매출액 제외','운영 비용 비율: 운영비/순매출액','연구개발비율: (연구개발비)/순매출액'
#,'현금 흐름 속도: 영업/경상부채로 인한 현금흐름','이자부 부채 이자율: 이자부부채/지분','세율 (A): 실효세율','주당 순가치(B): 주당 장부가액(B)'
#,'주당 순가치(A): 주당 장부가액(A)','주당 순가치(C): 주당 장부가치(C)','지난 4시즌간 지속적인 EPS: EPS-순소득','주당 현금 흐름'
#,'주당 수익(Yuan ¥): 주당 매출','주당 영업이익(Yuan ¥): 주당 영업이익','세전 1주당 순이익(위안 ¥): 세전 1주당 소득','실현된 매출 총이익 증가율'
#,'영업이익 증가율: 영업이익 증가율','세후 순이익 증가율: 순이익 증가율','정기 순이익 증가율 : 세금 증가 후 영업이익 지속','지속적인 순이익 증가율: 처분손익을 제외한 순이익 증가율'
#,'총 자산 증가율: 총 자산 증가율','순가치 증가율: 총 자본 증가율','총 자산 수익률 증가율: 총 자산 수익률', '현금 재투자 %: 현금 재투자 비율','전류비'
#,'빠른 비율: 산도 테스트','이자비용비율: 이자비용/총수익','총부채/총 순자산: 총부채/지분율','부채 비율 %: 부채/총 자산','순자산/자산: 자본/총자산','장기자금적합비율(A): (장기부채+지분)/고정자산'
#,'차입 의존성: 이자 부담 부채 비용','우발부채/순자산: 우발부채/지분','영업이익/기입자본: 영업이익/자본','세전순이익/기입자본: 세전소득/자본','재고 및 매출채권/순가치: (재고+매출채권)/지분'
#,'총 자산 회전율','매출채권회전율','평균 수집일: 미수금 일수','재고 회전율(회)','고정 자산 회전 빈도','순자산 회전율(회수): 자본 회전율','1인당 매출: 직원당 매출'
#,'1인당 영업이익: 직원당 운영 수익','1인당 할당 비율: 직원당 고정 자산','운용 자본 대 총 자산','빠른 자산/총 자산','유동자산/총자산','현금/총자산'
#,'신속한 자산/경상 부채', '현금/유동부채','유동자산부채','부채에 대한 운영 자금','재고/운전 자본','재고/유동부채','유동부채/부채','운영 자본/자본','유동부채/자본','유동자산에 대한 장기부채'
#,'총자산 대비 이익잉여금','총수입/총비용','총 비용/자산','유동자산 회전율: 유동자산 대 매출액','빠른 자산 회전율: 신속한 자산 판매','가동 자본 회전율: 영업 자본','현금 회전율: 현금 대 매출액'
#,'매출로의 현금 흐름','고정 자산 대 자산','유동부채','자본에 대한 유동부채','장기 부채에 대한 자본','총 자산에 대한 현금 흐름','부채로의 현금 흐름','자산에 대한 CFO','자본으로의 현금 흐름'
#,'유동자산에 대한 유동부채','책임 자산 플래그','총자산 대비 순이익','GNP 가격 대비 총자산','무신용 구간','매출총이익'
#,'주주 자본에 대한 순이익','자본부채','금융 레버리지(DFL)의 정도','이자보상비율(EB에 대한 이자비용)IT)','순이익 플래그','부채에 대한 지분']
# df.head()

# %% [markdown]
# # **EDA**

# %% [markdown]
# ## **데이터 확인**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
df.shape
# Out:
# (6819, 96)

# %%
df.describe(include='all')
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %% [markdown]
# ## **변수명 내 공백처리**

# %%
df.columns = df.columns.str.replace(' ','_')

# %% [markdown]
# ## **Y값 확인**
# 데이터 불균형 발생 -> 처리 필요

# %%
df["Bankrupt?"].value_counts(normalize=True).plot(
    kind="bar",
    xlabel="bankrupt",
    ylabel="frequency",
    title="class")
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
df["Bankrupt?"].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %% [markdown]
# ## **결측치 확인**
# 결측치 없음

# %%
df.columns[df.isna().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## **이상치 처리**

# %%
def outliers_removal(feature,feature_name,dataset):
    
    # Identify 25th & 75th quartiles

    q25, q75 = np.percentile(feature, 25), np.percentile(feature, 75)
    print('Quartile 25: {} | Quartile 75: {}'.format(q25, q75))
    feat_iqr = q75 - q25
    print('iqr: {}'.format(feat_iqr))
    
    feat_cut_off = feat_iqr * 1.5
    feat_lower, feat_upper = q25 - feat_cut_off, q75 + feat_cut_off
    print('Cut Off: {}'.format(feat_cut_off))
    print(feature_name +' Lower: {}'.format(feat_lower))
    print(feature_name +' Upper: {}'.format(feat_upper))
    
    outliers = [x for x in feature if x < feat_lower or x > feat_upper]
    print(feature_name + ' outliers for close to bankruptcy cases: {}'.format(len(outliers)))
    #print(feature_name + ' outliers:{}'.format(outliers))

    dataset = dataset.drop(dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index)
    print('-' * 65)
    
    return dataset

for col in df:
    new_df = outliers_removal(df[col],str(col),df)
# Out:
# Quartile 25: 0.0 | Quartile 75: 0.0
# iqr: 0.0
# Cut Off: 0.0
# Bankrupt? Lower: 0.0
# Bankrupt? Upper: 0.0
# Bankrupt? outliers for close to bankruptcy cases: 220
# -----------------------------------------------------------------
# Quartile 25: 0.476527080388047 | Quartile 75: 0.535562813825379
# iqr: 0.05903573343733198
# Cut Off: 0.08855360015599797
# _ROA(C)_before_interest_and_depreciation_before_interest Lower: 0.38797348023204903
# _ROA(C)_before_interest_and_depreciation_before_interest Upper: 0.624116413981377
# _ROA(C)_before_interest_and_depreciation_before_interest outliers for close to bankruptcy cases: 391
# -----------------------------------------------------------------
# Quartile 25: 0.53554295682512 | Quartile 75: 0.58915721761884
# iqr: 0.05361426079372
# Cut Off: 0.08042139119058
# _ROA(A)_before_interest_and_%_after_tax Lower: 0.45512156563454
# _ROA(A)_before_interest_and_%_after_tax Upper: 0.66957860880942
# ...

# %% [markdown]
# ## **데이터 타입별 변수 분리**

# %%
# 변수를 데이터 타입별 분류
from pandas import DataFrame, Series
def get_variable_types(df: DataFrame) -> dict:
    variable_types: dict = {
        'Numeric': [],
        'Binary': [],
        'Date': [],
        'Symbolic': []
    }
    for c in df.columns:
        uniques = df[c].dropna(inplace=False).unique()
        if len(uniques) == 2:
            variable_types['Binary'].append(c)
            df[c].astype('bool')
        elif len(uniques) == 1:
            variable_types['Binary'].append(c)
            df[c].astype('bool')
        elif df[c].dtype == 'datetime64':
            variable_types['Date'].append(c)
        elif df[c].dtype == 'int':
            variable_types['Numeric'].append(c)
        elif df[c].dtype == 'float':
            variable_types['Numeric'].append(c)
        else:
            df[c].astype('category')
            variable_types['Symbolic'].append(c)

    return variable_types

# %% [markdown]
# ## **범주형 변수 확인**
# -> 데이터 불균형 매우 크다는 문제점 존재 -> 종속변수를 제외한 범주형 변수들은 삭제해도 될 것 같음

# %%
bi_value = get_variable_types(df)['Binary']
bi_df = df[bi_value]
bi_df.head()
# Out:
#    Bankrupt?  _Liability-Assets_Flag  _Net_Income_Flag
# 0          1                       0                 1
# 1          1                       0                 1
# 2          1                       0                 1
# 3          1                       0                 1
# 4          1                       0                 1

# %%
bi_df['_Liability-Assets_Flag'].value_counts()
# Out:
# 0    6811
# 1       8
# Name: _Liability-Assets_Flag, dtype: int64

# %%
df["_Liability-Assets_Flag"].value_counts(normalize=True).plot(
    kind="bar",
    xlabel="bankrupt",
    ylabel="frequency",
    title="class")

# %%
bi_df['_Net_Income_Flag'].value_counts()
# Out:
# 1    6819
# Name: _Net_Income_Flag, dtype: int64

# %%
df["_Net_Income_Flag"].value_counts(normalize=True).plot(
    kind="bar",
    xlabel="bankrupt",
    ylabel="frequency",
    title="class")

# %% [markdown]
# ## **연속형 변수 확인**

# %%
variables = get_variable_types(df)['Numeric']
numeric_df = df[variables]
numeric_df.head()
# Out:
#    _ROA(C)_before_interest_and_depreciation_before_interest  \
# 0                                           0.370594
# 1                                           0.464291
# 2                                           0.426071
# 3                                           0.399844
# 4                                           0.465022
#
#    _ROA(A)_before_interest_and_%_after_tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#    _ROA(B)_before_interest_and_depreciation_after_tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
# ...

# %% [markdown]
# ### 히스토그램

# %%
numeric_df.hist(figsize = (100,100))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff25099eeb0>,
# ...
#       dtype=object)

# %% [markdown]
# ### **종속변수 없이 상관관계 확인**
# * 상관관계가 매우 높은 변수들은 다중공선성 문제가 발생하기 때문에 삭제
# * 보통 상관계수가 0.9 이상이면 다중공선성이 발생한다고 판단
# * 상관계수가 0.9 이상인 변수 쌍의 변수 삭제

# %%
import seaborn as sns
plt.figure(figsize = (100,100))
sns.heatmap(numeric_df.corr(), cmap = "Blues")

# %%
nucorr = abs(numeric_df.corr())
nucorr7 = nucorr[(0.7 < nucorr) & (nucorr < 1.0)].fillna(0)
plt.figure(figsize = (100,100))
sns.heatmap(nucorr7, cmap = "Blues")

# %%
nucorr7.columns
# Out:
# Index(['_ROA(C)_before_interest_and_depreciation_before_interest',
#        '_ROA(A)_before_interest_and_%_after_tax',
#        '_ROA(B)_before_interest_and_depreciation_after_tax',
#        '_Operating_Gross_Margin', '_Realized_Sales_Gross_Margin',
#        '_Operating_Profit_Rate', '_Pre-tax_net_Interest_Rate',
#        '_After-tax_net_Interest_Rate',
#        '_Non-industry_income_and_expenditure/revenue',
#        '_Continuous_interest_rate_(after_tax)', '_Operating_Expense_Rate',
#        '_Research_and_development_expense_rate', '_Cash_flow_rate',
#        '_Interest-bearing_debt_interest_rate', '_Tax_rate_(A)',
#        '_Net_Value_Per_Share_(B)', '_Net_Value_Per_Share_(A)',
#        '_Net_Value_Per_Share_(C)', '_Persistent_EPS_in_the_Last_Four_Seasons',
#        '_Cash_Flow_Per_Share', '_Revenue_Per_Share_(Yuan_¥)',
#        '_Operating_Profit_Per_Share_(Yuan_¥)',
#        '_Per_Share_Net_profit_before_tax_(Yuan_¥)',
#        '_Realized_Sales_Gross_Profit_Growth_Rate',
# ...

# %%
len(nucorr7)
# Out:
# 93

# %% [markdown]
# 상관행렬은 대칭행렬이므로 대각원소를 기준으로 아래값들 삭제

# %%
n = 0
for i in range(len(nucorr7)):
  row = nucorr7.index[i]
  i += 1
  for col in variables:
    n += 1
    if i > n :
      nucorr7.loc[row, col] = 0
  n = 0
nucorr7
# Out:
#                                                     _ROA(C)_before_interest_and_depreciation_before_interest  \
# _ROA(C)_before_interest_and_depreciation_before...                                                0.0
# _ROA(A)_before_interest_and_%_after_tax                                                           0.0
# _ROA(B)_before_interest_and_depreciation_after_tax                                                0.0
# _Operating_Gross_Margin                                                                           0.0
# _Realized_Sales_Gross_Margin                                                                      0.0
# ...                                                                                               ...
# _Net_Income_to_Stockholder's_Equity                                                               0.0
# _Liability_to_Equity                                                                              0.0
# ...

# %% [markdown]
# 상관관계가 0.7 이상인 변수쌍

# %%
high_corr = []
for i in variables:
  col = i
  for k in range(93):
    row = nucorr7.index[k]
    if nucorr7.loc[row, col] != 0:
      high_corr.append([row, col])
high_corr
# Out:
# [['_ROA(C)_before_interest_and_depreciation_before_interest',
#   '_ROA(A)_before_interest_and_%_after_tax'],
#  ['_ROA(C)_before_interest_and_depreciation_before_interest',
#   '_ROA(B)_before_interest_and_depreciation_after_tax'],
#  ['_ROA(A)_before_interest_and_%_after_tax',
#   '_ROA(B)_before_interest_and_depreciation_after_tax'],
#  ['_Operating_Gross_Margin', '_Realized_Sales_Gross_Margin'],
#  ['_Operating_Profit_Rate', '_Pre-tax_net_Interest_Rate'],
#  ['_Operating_Profit_Rate', '_After-tax_net_Interest_Rate'],
#  ['_Pre-tax_net_Interest_Rate', '_After-tax_net_Interest_Rate'],
#  ['_Operating_Profit_Rate', '_Continuous_interest_rate_(after_tax)'],
#  ['_Pre-tax_net_Interest_Rate', '_Continuous_interest_rate_(after_tax)'],
#  ['_After-tax_net_Interest_Rate', '_Continuous_interest_rate_(after_tax)'],
#  ['_Net_Value_Per_Share_(B)', '_Net_Value_Per_Share_(A)'],
#  ['_Net_Value_Per_Share_(B)', '_Net_Value_Per_Share_(C)'],
# ...

# %% [markdown]
# 상관관계가 0.9인 변수쌍 (앞과 동일한 과정 진행)

# %%
nucorr9 = nucorr[(0.9 < nucorr) & (nucorr < 1.0)].fillna(0)

n = 0
for i in range(len(nucorr9)):
  row = nucorr9.index[i]
  i += 1
  for col in variables:
    n += 1
    if i > n :
      nucorr9.loc[row, col] = 0
  n = 0

most_high_corr = []
for i in variables:
  col = i
  for k in range(93):
    row = nucorr9.index[k]
    if nucorr9.loc[row, col] != 0:
      most_high_corr.append([row, col])
most_high_corr
# Out:
# [['_ROA(C)_before_interest_and_depreciation_before_interest',
#   '_ROA(A)_before_interest_and_%_after_tax'],
#  ['_ROA(C)_before_interest_and_depreciation_before_interest',
#   '_ROA(B)_before_interest_and_depreciation_after_tax'],
#  ['_ROA(A)_before_interest_and_%_after_tax',
#   '_ROA(B)_before_interest_and_depreciation_after_tax'],
#  ['_Operating_Gross_Margin', '_Realized_Sales_Gross_Margin'],
#  ['_Operating_Profit_Rate', '_Pre-tax_net_Interest_Rate'],
#  ['_Pre-tax_net_Interest_Rate', '_After-tax_net_Interest_Rate'],
#  ['_Operating_Profit_Rate', '_Continuous_interest_rate_(after_tax)'],
#  ['_Pre-tax_net_Interest_Rate', '_Continuous_interest_rate_(after_tax)'],
#  ['_After-tax_net_Interest_Rate', '_Continuous_interest_rate_(after_tax)'],
#  ['_Net_Value_Per_Share_(B)', '_Net_Value_Per_Share_(A)'],
#  ['_Net_Value_Per_Share_(B)', '_Net_Value_Per_Share_(C)'],
#  ['_Net_Value_Per_Share_(A)', '_Net_Value_Per_Share_(C)'],
#  ['_Persistent_EPS_in_the_Last_Four_Seasons',
# ...

# %%
len(most_high_corr)
# Out:
# 26

# %%
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, verts=<deprecated parameter>, edgecolors=None, *, plotnonfinite=False, data=None, **kwargs)>

# %%
for i in range(len(most_high_corr)):
  x = most_high_corr[i][0]
  y = most_high_corr[i][1]
  plt.scatter(df[x], df[y])
  plt.title(most_high_corr[i])
  plt.show()

# %% [markdown]
# ### **종속변수 포함해서 상관관계 확인**

# %%
variables.append('Bankrupt?')

# %%
numeric_df_Y = df[variables]
nu_corr_df = abs(pd.DataFrame(numeric_df_Y.corr().loc['Bankrupt?'])).sort_values("Bankrupt?")
nu_corr_df[nu_corr_df['Bankrupt?'] >= 0.2]
# Out:
#                                                     Bankrupt?
# _Per_Share_Net_profit_before_tax_(Yuan_¥)            0.201395
# _Net_profit_before_tax/Paid-in_capital               0.207857
# _Retained_Earnings_to_Total_Assets                   0.217779
# _Persistent_EPS_in_the_Last_Four_Seasons             0.219560
# _Debt_ratio_%                                        0.250161
# _Net_worth/Assets                                    0.250161
# _ROA(C)_before_interest_and_depreciation_before...   0.260807
# _ROA(B)_before_interest_and_depreciation_after_tax   0.273051
# _ROA(A)_before_interest_and_%_after_tax              0.282941
# _Net_Income_to_Total_Assets                          0.315457
# Bankrupt?                                            1.000000

# %% [markdown]
# # **데이터 전처리 (이것저것)**

# %% [markdown]
# ### **범주형 변수 삭제**

# %%
df.drop(['_Liability-Assets_Flag','_Net_Income_Flag'], axis = 1, inplace = True)

# %% [markdown]
# ### **데이터 정규화**
# 데이터의 특징을 잘 알지 못하기 때문에 가장 무난하게 쓰여지는 StandardScaler를 사용하여 데이터 정규화

# %%
X = df.drop('Bankrupt?', axis = 1)
Y = df['Bankrupt?']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_std = scaler.fit_transform(X)
X = pd.DataFrame(df_std, columns = X.columns)
X.head()
# Out:
#    _ROA(C)_before_interest_and_depreciation_before_interest  \
# 0                                          -2.217909
# 1                                          -0.673828
# 2                                          -1.303672
# 3                                          -1.735886
# 4                                          -0.661778
#
#    _ROA(A)_before_interest_and_%_after_tax  \
# 0                                -2.045798
# 1                                -0.311068
# 2                                -0.908420
# 3                                -1.636209
# 4                                -0.307745
#
#    _ROA(B)_before_interest_and_depreciation_after_tax  \
# 0                                          -2.400361
# 1                                          -0.598450
# 2                                          -1.319910
# 3                                          -1.556340
# 4                                          -0.508050
#
# ...

# %% [markdown]
# ## **데이터 불균형 처리**

# %% [markdown]
# * oversampling <br>
# : 이상 데이터와 같이 적은 데이터 세트를 증식하여 학습을 위한 충분한 데이터를 확보하는 방법으로, 동일한 데이터의 단순 증식은 과적합을 유발할 수 있기 때문에 의미가 없으므로 원본 데이터의 피처값들을 아주 약간씩 변형하여 증식 <br>
# * undersampling <br>
# :  다수 범주의 값들을 감소시키고 데이터 비율을 맞춰서 재현율을 향상시키는 샘플링 방법
#
# <br>
#
# * SMOTE 방식 사용 <br>
# : 오버샘플링 기법 중 합성데이터를 생성하는 방식으로 가장 많이 사용되고 있는 모델로 다수 클래스를 샘플링하고 기존 소수 샘플을 보간하여 새로운 소수 인스턴스를 합성

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_sm, y_sm = smote.fit_resample(X, y)
print("SMOTE 적용 전 학습용 피처/레이블 데이터 세트 : ", X.shape, y.shape)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트 :', X_sm.shape, y_sm.shape)
print('SMOTE 적용 후 값의 분포 :\n',pd.Series(y_sm).value_counts())
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트 :  (5114, 16) (5114,)
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트 : (9904, 16) (9904,)
# SMOTE 적용 후 값의 분포 :
#  0    4952
# 1    4952
# Name: Bankrupt?, dtype: int64

# %% [markdown]
# * SMOTE-Tomek <br>
# :  Oversampling과 Undersampling을 함께 수행하는 방법

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks

smoteto = SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))
X_smt, y_smt = smoteto.fit_resample(X, y)
print("SMOTE-Tomek 적용 전 학습용 피처/레이블 데이터 세트 : ", X.shape, y.shape)
print('SMOTE-Tomek 적용 후 학습용 피처/레이블 데이터 세트 :', X_smt.shape, y_smt.shape)
print('SMOTE-Tomek 적용 후 값의 분포 :\n',pd.Series(y_smt).value_counts())
# Out:
# SMOTE-Tomek 적용 전 학습용 피처/레이블 데이터 세트 :  (5114, 16) (5114,)
# SMOTE-Tomek 적용 후 학습용 피처/레이블 데이터 세트 : (9903, 16) (9903,)
# SMOTE-Tomek 적용 후 값의 분포 :
#  1    4952
# 0    4951
# Name: Bankrupt?, dtype: int64

# %% [markdown]
# * ADASYN <br>
# : ADASYN은 각 관측치마다 생성하는 샘플의 수가 다르다는 점이 특징

# %%
from imblearn.over_sampling import ADASYN

adasyn = ADASYN(random_state=22)
X_ad, y_ad = adasyn.fit_resample(X, y)
print("ADASYN 적용 전 학습용 피처/레이블 데이터 세트 : ", X.shape, y.shape)
print('ADASYN 적용 후 학습용 피처/레이블 데이터 세트 :', X_ad.shape, y_ad.shape)
print('ADASYN 적용 후 값의 분포 :\n',pd.Series(y_ad).value_counts())

# %% [markdown]
# ## **Feature Selection_Permutation Importance**

# %%
pip install eli5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state = 42)

# %%
import eli5 
from eli5.sklearn import PermutationImportance 
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier().fit(X_train, y_train)

perm = PermutationImportance(model, scoring = "accuracy", random_state = 42).fit(X_test, y_test) 
eli5.show_weights(perm, top = 70, feature_names = X_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0236
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 _Interest_Expense_Ratio
# ...

# %% [markdown]
# ## **importance가 높은 변수들로만 데이터셋 생성**

# %%
new_X = X[['_Interest_Expense_Ratio',"_Net_Income_to_Stockholder's_Equity",'_Degree_of_Financial_Leverage_(DFL)','_Borrowing_dependency','_Net_Income_to_Total_Assets',
'_Operating_profit_per_person','_Working_Capital_to_Total_Assets','_Continuous_Net_Profit_Growth_Rate','_Cash_Flow_to_Sales','_Persistent_EPS_in_the_Last_Four_Seasons','_Quick_Assets/Total_Assets',
'_Continuous_interest_rate_(after_tax)','_Liability_to_Equity','_Per_Share_Net_profit_before_tax_(Yuan_¥)','_Interest_Coverage_Ratio_(Interest_expense_to_EBIT)',
'_Non-industry_income_and_expenditure/revenue','_CFO_to_Assets','_Total_Asset_Growth_Rate','_Current_Liabilities/Liability','_Realized_Sales_Gross_Profit_Growth_Rate',
'_Retained_Earnings_to_Total_Assets','_ROA(B)_before_interest_and_depreciation_after_tax','_Current_Liability_to_Liability','_Current_Assets/Total_Assets','_Inventory/Current_Liability',
'_Cash/Total_Assets','_After-tax_Net_Profit_Growth_Rate','_Operating_Profit_Growth_Rate','_Contingent_liabilities/Net_worth','_Operating_Expense_Rate','_Operating_profit/Paid-in_capital',
'_Total_expense/Assets','_Cash_Turnover_Rate','_Current_Asset_Turnover_Rate','_Research_and_development_expense_rate','_Cash_Flow_to_Total_Assets','_Debt_ratio_%','_Inventory_Turnover_Rate_(times)']]

# %% [markdown]
# ## **상관계수 0.9 이상인 변수 확인**

# %%
new_cor = abs(new_X.corr())
new_cor
# Out:
#                                                     _Interest_Expense_Ratio  \
# _Interest_Expense_Ratio                                            1.000000
# _Net_Income_to_Stockholder's_Equity                                0.003604
# _Degree_of_Financial_Leverage_(DFL)                                0.016829
# _Borrowing_dependency                                              0.007844
# _Net_Income_to_Total_Assets                                        0.004969
# _Operating_profit_per_person                                       0.008881
# _Working_Capital_to_Total_Assets                                   0.014455
# _Continuous_Net_Profit_Growth_Rate                                 0.001145
# _Cash_Flow_to_Sales                                                0.000038
# _Persistent_EPS_in_the_Last_Four_Seasons                           0.000007
# _Quick_Assets/Total_Assets                                         0.016619
# ...

# %%
new_cor = new_cor[(0.9 < new_cor) & (new_cor < 1.0)].fillna(0)

n = 0
for i in range(len(new_cor)):
  row = new_cor.index[i]
  i += 1
  for col in new_cor.columns:
    n += 1
    if i > n :
      new_cor.loc[row, col] = 0
  n = 0

most_high_corr = []
for col in new_cor.columns:
  for k in range(len(new_cor)):
    row = new_cor.index[k]
    if new_cor.loc[row, col] != 0:
      most_high_corr.append([row, col])
most_high_corr
# Out:
# [['_Borrowing_dependency', '_Liability_to_Equity'],
#  ['_Persistent_EPS_in_the_Last_Four_Seasons',
#   '_Per_Share_Net_profit_before_tax_(Yuan_¥)'],
#  ['_Net_Income_to_Total_Assets',
#   '_ROA(B)_before_interest_and_depreciation_after_tax']]

# %% [markdown]
# ## **다중공선성을 이용한 변수 제거**

# %% [markdown]
# R로 데이터 이동

# %%
new_X.head()
# Out:
#    _Interest_Expense_Ratio  _Net_Income_to_Stockholder's_Equity  \
# 0                -0.092520                            -0.861611
# 1                 0.372093                            -0.029804
# 2                -0.120983                            -0.249820
# 3                -0.067866                            -0.392864
# 4                 0.450626                            -0.029564
#
#    _Degree_of_Financial_Leverage_(DFL)  _Borrowing_dependency  \
# 0                            -0.060031               0.959784
# 1                            15.129816               0.129305
# 2                            -0.062961               0.272560
# 3                            -0.053903               0.312459
# 4                            -0.178037               0.022791
#
#    _Net_Income_to_Total_Assets  _Operating_profit_per_person  \
# 0                    -2.254317                     -0.237123
# 1                    -0.309033                     -0.277557
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Bankrupt?, dtype: int64

# %%
newXY = pd.concat([new_X,Y],axis=1)
newXY.to_csv('newXY_df.csv')

# %%
import pandas as pd
pd.set_option('display.max_rows', 10000)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns 
vif.sort_values('VIF Factor', inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/stats/outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %% [markdown]
# glm & 'both' 이용한 결과

# %% [markdown]
# ![사본 -스크린샷(145).png](data:image/png;base64,...)

# %%
new_X.columns
# Out:
# Index(['_Interest_Expense_Ratio', '_Net_Income_to_Stockholder's_Equity',
#        '_Degree_of_Financial_Leverage_(DFL)', '_Borrowing_dependency',
#        '_Net_Income_to_Total_Assets', '_Operating_profit_per_person',
#        '_Working_Capital_to_Total_Assets',
#        '_Continuous_Net_Profit_Growth_Rate', '_Cash_Flow_to_Sales',
#        '_Persistent_EPS_in_the_Last_Four_Seasons',
#        '_Quick_Assets/Total_Assets', '_Continuous_interest_rate_(after_tax)',
#        '_Liability_to_Equity', '_Per_Share_Net_profit_before_tax_(Yuan_¥)',
#        '_Interest_Coverage_Ratio_(Interest_expense_to_EBIT)',
#        '_Non-industry_income_and_expenditure/revenue', '_CFO_to_Assets',
#        '_Total_Asset_Growth_Rate', '_Current_Liabilities/Liability',
#        '_Realized_Sales_Gross_Profit_Growth_Rate',
#        '_Retained_Earnings_to_Total_Assets',
#        '_ROA(B)_before_interest_and_depreciation_after_tax',
#        '_Current_Liability_to_Liability', '_Current_Assets/Total_Assets',
# ...

# %%
new_X = new_X[['_Borrowing_dependency','_Net_Income_to_Total_Assets','_Working_Capital_to_Total_Assets','_Persistent_EPS_in_the_Last_Four_Seasons','_Quick_Assets/Total_Assets',
               '_Liability_to_Equity', '_Per_Share_Net_profit_before_tax_(Yuan_¥)','_Current_Liabilities/Liability','_Current_Assets/Total_Assets','_Cash/Total_Assets',
               '_Contingent_liabilities/Net_worth','_Operating_profit/Paid-in_capital','_Total_expense/Assets','_Cash_Turnover_Rate','_Cash_Flow_to_Total_Assets','_Debt_ratio_%']]

# %%
X_train, X_test, y_train, y_test = train_test_split(new_X, Y, test_size = 0.25, random_state = 42)

# %% [markdown]
# ## **변수 개수를 선정하여 선택**

# %%
from sklearn.feature_selection import f_regression, SelectKBest
selector = SelectKBest(score_func=f_regression, k=5)
X_train_selected = selector.fit_transform(X_train, y_train)
X_test_selected = selector.transform(X_test)
X_train_selected.shape, X_test_selected.shape
all_names = X_train.columns
selected_mask = selector.get_support()
selected_names = all_names[selected_mask]
unselected_names = all_names[~selected_mask]
print('Selected names: ', selected_names)
print('Unselected names: ', unselected_names)
# Out:
# Selected names:  Index(['_Borrowing_dependency', '_Net_Income_to_Total_Assets',
#        '_Persistent_EPS_in_the_Last_Four_Seasons', '_Liability_to_Equity',
#        '_Debt_ratio_%'],
#       dtype='object')
# Unselected names:  Index(['_Working_Capital_to_Total_Assets', '_Quick_Assets/Total_Assets',
#        '_Per_Share_Net_profit_before_tax_(Yuan_¥)',
#        '_Current_Liabilities/Liability', '_Current_Assets/Total_Assets',
#        '_Cash/Total_Assets', '_Contingent_liabilities/Net_worth',
#        '_Operating_profit/Paid-in_capital', '_Total_expense/Assets',
#        '_Cash_Turnover_Rate', '_Cash_Flow_to_Total_Assets'],
#       dtype='object')

# %% [markdown]
# # **최종 전처리**

# %%
df = pd.read_csv("/content/drive/MyDrive/data.csv")
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
df.columns = df.columns.str.replace(' ','_')

# %% [markdown]
# ## **범주형 변수 삭제**

# %%
df.drop(['_Liability-Assets_Flag','_Net_Income_Flag'], axis = 1, inplace = True)

# %% [markdown]
# ## **이상치 처리**

# %%
def outliers_removal(feature,feature_name,dataset):
    
    # Identify 25th & 75th quartiles

    q25, q75 = np.percentile(feature, 25), np.percentile(feature, 75)
    feat_iqr = q75 - q25
    
    feat_cut_off = feat_iqr * 1.5
    feat_lower, feat_upper = q25 - feat_cut_off, q75 + feat_cut_off
    
    outliers = [x for x in feature if x < feat_lower or x > feat_upper]

    dataset = dataset.drop(dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index)
    
    return dataset

for col in df:
    new_df = outliers_removal(df[col],str(col),df)

# %% [markdown]
# ## **상관관계 0.9 이상인 변수 삭제**

# %%
X = df.drop('Bankrupt?', axis = 1)
y = df['Bankrupt?']

# %%
cor_matrix = df.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool)) #

dropped_cols = set()
for feature in upper_tri.columns:
    if any(upper_tri[feature] > 0.9): # feature로 들어온 변수와의 상관관계가 0.9 이상인게 하나라도 있으면
        dropped_cols.add(feature) # 해당 feature를 dropped_cols set에 포함시킴 (set의 특성상 중복이 제거되며 추가)

# %%
# 상관관계 0.9 이상이 존재하는 변수 전체 삭제
X = X.drop(dropped_cols,axis=1)

# %% [markdown]
# ## **데이터 표준화**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_std = scaler.fit_transform(X)
X = pd.DataFrame(df_std, columns = X.columns)

# %% [markdown]
# ## **데이터 불균형 처리**

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_sm, y_sm = smote.fit_resample(X, y)
print("SMOTE 적용 전 학습용 피처/레이블 데이터 세트 : ", X.shape, y.shape)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트 :', X_sm.shape, y_sm.shape)
print('SMOTE 적용 후 값의 분포 :\n',pd.Series(y_sm).value_counts())
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트 :  (6819, 74) (6819,)
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트 : (13198, 74) (13198,)
# SMOTE 적용 후 값의 분포 :
#  1    6599
# 0    6599
# Name: Bankrupt?, dtype: int64

# %% [markdown]
# # **모델링**

# %%
print(X_sm.shape)
print(y_sm.shape)
# Out:
# (13198, 74)
# (13198,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.3, stratify = y_sm) # 데이터 분할

# %% [markdown]
# ## **1. SVM**

# %%
sw_train = class_weight.compute_sample_weight(class_weight = 'balanced', y = y_train) 
    
steps = [('SVM', SVC(cache_size=7000))]
pipeline = Pipeline(steps)
    
param_grid = {
  'SVM__C':[0.01,0.1,1,10],
  'SVM__gamma':[0.1,0.01,0.001,0.0001],
  'SVM__kernel':['rbf']}
    
f1 = make_scorer(f1_score)
grid = GridSearchCV(pipeline,param_grid=param_grid, cv=5, scoring=f1, verbose=0) 
grid.fit(X_train, y_train, SVM__sample_weight = sw_train)
    
print("best parameters: ")
print(grid.best_params_)
    
model = grid.best_estimator_
y_pred = model.predict(X_test)
    
print("f1 score is %.2f "%f1_score(y_test, y_pred))
print("Precision: %.2f" %precision_score(y_test, y_pred))
print("Recall: %.2f" %recall_score(y_test, y_pred))
print("Precision: %.2f" %precision_score(y_test, y_pred))
plot_confusion_matrix(model, X_test,  y_test, values_format='d')
# Out:
# best parameters:
# {'SVM__C': 10, 'SVM__gamma': 0.1, 'SVM__kernel': 'rbf'}
# f1 score is 0.99
# Precision: 0.99
# Recall: 0.98
# Precision: 0.99

# %% [markdown]
# ## **2. RandomForestClassifier**

# %%
from sklearn.ensemble import RandomForestClassifier

param_grid ={
    'n_estimators':[100, 200],
    'max_depth':[6,8,10,12],
    'min_samples_leaf':[3, 5, 7, 9],
    'min_samples_split':[3, 7, 11, 15]}
    
rf = RandomForestClassifier(random_state = 0)
f1 = make_scorer(f1_score)
grid = GridSearchCV(rf, param_grid=param_grid, cv=5, scoring=f1, verbose=0) 
grid.fit(X_train, y_train)
    
print("best parameters: ")
print(grid.best_params_)
    
model = grid.best_estimator_
y_pred = model.predict(X_test)
    
print("f1 score is %.2f "%f1_score(y_test, y_pred))
print("Precision: %.2f" %precision_score(y_test, y_pred))
print("Recall: %.2f" %recall_score(y_test, y_pred))
print("Precision: %.2f" %precision_score(y_test, y_pred))
plot_confusion_matrix(model, X_test, y_test, values_format='d')
# Out:
# best parameters:
# {'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 100}
# f1 score is 0.97
# Precision: 0.95
# Recall: 1.00
# Precision: 0.95

# %% [markdown]
# ## **3. Adaboost**

# %%
from sklearn.ensemble import AdaBoostClassifier

param_grid ={
    'n_estimators':[30, 50, 70, 100],
    'learning_rate':[0.1, 0.5, 1.0, 1.5]}

ada = AdaBoostClassifier()
f1 = make_scorer(f1_score)
grid = GridSearchCV(ada, param_grid=param_grid, cv=5, scoring=f1, verbose=0) 
grid.fit(X_train, y_train)
    
print("best parameters: ")
print(grid.best_params_)
    
model = grid.best_estimator_
y_pred = model.predict(X_test)
    
print("f1 score is %.2f "%f1_score(y_test, y_pred))
print("Precision: %.2f" %precision_score(y_test, y_pred))
print("Recall: %.2f" %recall_score(y_test, y_pred))
print("Precision: %.2f" %precision_score(y_test, y_pred))
plot_confusion_matrix(model, X_test, y_test, values_format='d')
# Out:
# best parameters:
# {'learning_rate': 1.0, 'n_estimators': 100}
# f1 score is 0.94
# Precision: 0.92
# Recall: 0.95
# Precision: 0.92

# %% [markdown]
# ## **4. Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingClassifier

parameters = {
    'max_depth':[1,2,3,4,5], 
    'learning_rate':[0.1,0.08, 0.06, 0.04, 0.02]}

gb = GradientBoostingClassifier(random_state=0)
f1 = make_scorer(f1_score)
grid = GridSearchCV(gb, param_grid=param_grid, cv=5, scoring=f1, verbose=0)
grid.fit(X_train, y_train)

print("best parameters: ")
print(grid.best_params_)
    
model = grid.best_estimator_
y_pred = model.predict(X_test)
    
print("f1 score is %.2f "%f1_score(y_test, y_pred))
print("Precision: %.2f" %precision_score(y_test, y_pred))
print("Recall: %.2f" %recall_score(y_test, y_pred))
print("Precision: %.2f" %precision_score(y_test, y_pred))
plot_confusion_matrix(model, X_test, y_test, values_format='d')
# Out:
# best parameters:
# {'learning_rate': 0.5, 'n_estimators': 100}
# f1 score is 0.98
# Precision: 0.96
# Recall: 0.99
# Precision: 0.96

# %% [markdown]
# ## **+) Voting**

# %%
#from sklearn.datasets import load_iris
#from sklearn.ensemble import RandomForestClassifier,VotingClassifier
#from sklearn.linear_model import LogisticRegression
#from sklearn.svm import SVC
#from sklearn.metrics import accuracy_score
#from sklearn.model_selection import train_test_split

#log_model = LogisticRegression()
#rnd_model = RandomForestClassifier()
#svm_model = SVC()
#ada_model = AdaBoostClassifier()

#voting_model = VotingClassifier(
#    estimators=[('lr',log_model),('rf',rnd_model),('svc',svm_model)], # 3개의 약한 학습기
#    voting='hard' # 직접 투표(hard voting)
#)
#voting_model.fit(X_train,y_train)

#for model in (log_model,rnd_model,svm_model,voting_model):
#  model.fit(X_train,y_train)
#  y_pred = model.predict(X_test)
#  print(model.__class__.__name__," : ",accuracy_score(y_test,y_pred))
 
#y_pred = voting_model.predict(X_test)
#f1_score(y_test, y_pred)

# %% [markdown]
# # **최종모델**
# ## **Gradient Boost Machine 채택**
# **채택이유** : f1-score 기준으로 본다면 SVM의 성능이 가장 좋게 나왔으나, 프로젝트의 목적이 파산에 어떤 요인들이 영향을 미치는지 파악하고 시사점을 도출하는 것이기에 어떠한 요인으로 인해 파산으로, 혹은 비파산으로 분류되었는지 알 수 없는 SVM보다는 feature_importance를 확인할 수 있는 tree기반 모델이 더욱 적합하다고 생각됨. 보통 SVM은 현재 분류기법 중 최상의 기법으로 평가받고 있기에 해당 모델의 f1-score를 기준으로 가장 차이가 적게 나는 모델을 선정하고자 함. 따라서, SVM과 0.01의 차이밖에 나지 않고 tree 기반의 모델인 GBM을 최종 모델로 선정.

# %% [markdown]
# ![스크린샷(154).png](data:image/png;base64,...)

# %% [markdown]
# ## **feature importance**
# GradientBoostClassifier model의 결과를 이용하여 feature importance 확인 <br>

# %%
ft_importance_values = model.feature_importances_

ft_series = pd.Series(ft_importance_values, index = X_train.columns)
ft_top20 = ft_series.sort_values(ascending=False)[:20]

ft_top20
# Out:
# _Persistent_EPS_in_the_Last_Four_Seasons                    0.371751
# _Non-industry_income_and_expenditure/revenue                0.119216
# _Debt_ratio_%                                               0.081797
# _Borrowing_dependency                                       0.075490
# _Interest_Expense_Ratio                                     0.048135
# _Operating_profit_per_person                                0.035283
# _Net_Income_to_Stockholder's_Equity                         0.030678
# _Cash_Turnover_Rate                                         0.027721
# _Current_Liability_to_Assets                                0.020919
# _Total_income/Total_expense                                 0.019426
# _Inventory/Working_Capital                                  0.016429
# _Contingent_liabilities/Net_worth                           0.015307
# _Equity_to_Long-term_Liability                              0.011512
# _Fixed_Assets_Turnover_Frequency                            0.009114
# ...

# %%
plt.figure(figsize=(8,6))
plt.title('Feature Importance Top 20')
sns.barplot(x=ft_top20, y=ft_top20.index)
plt.show()

# %% [markdown]
# ## **ROC curve**

# %%
from sklearn.metrics import roc_auc_score, roc_curve
fpr_gbm, tpr_gbm, cutoff_gbm = roc_curve(y_test, grid.predict_proba(X_test)[:, 1], pos_label=1)
plt.plot(fpr_gbm, tpr_gbm, label="Gradient Boosting Classifier ROC Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.legend(loc=4)
plt.show()

# %%
auc_gbm = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
print("Gradient Boosting Machine의 AUC : {:.3f}".format(auc_gbm))
# Out:
# Gradient Boosting Machine의 AUC : 0.995
